# %% [markdown]
# # Working with Data
# ## Python File Open

# %%
file = open('data.txt', 'w')
for i in range(10,100,3):
  file.write(str(i)+"\t"+str(i*10-40)+"\n")
file.close()

# %%
file = open('data.txt', 'r')
data = file.read()
x = []
y = []
print(data)
file.seek(0)

for line in file:
  line_split = line.replace('\n', '').split('\t')
  x.append(line_split[0])
  y.append(line_split[1])

file.close()

print(x)
print(y)
# Out:
# 10	60
# 13	90
# 16	120
# 19	150
# 22	180
# 25	210
# 28	240
# 31	270
# 34	300
# 37	330
# 40	360
# 43	390
# 46	420
# 49	450
# 52	480
# 55	510
# 58	540
# 61	570
# 64	600
# 67	630
# 70	660
# 73	690
# 76	720
# 79	750
# 82	780
# 85	810
# 88	840
# 91	870
# 94	900
# 97	930
#
# ['10', '13', '16', '19', '22', '25', '28', '31', '34', '37', '40', '43', '46', '49', '52', '55', '58', '61', '64', '67', '70', '73', '76', '79', '82', '85', '88', '91', '94', '97']
# ['60', '90', '120', '150', '180', '210', '240', '270', '300', '330', '360', '390', '420', '450', '480', '510', '540', '570', '600', '630', '660', '690', '720', '750', '780', '810', '840', '870', '900', '930']

# %%
with open('data.txt', 'r') as file:
  data = file.read()
  x = []
  y = []
  print(data)
  file.seek(0)

  for line in file:
    line_split = line.replace('\n', '').split('\t')
    x.append(line_split[0])
    y.append(line_split[1])

  print(x)
  print(y)
# Out:
# 10	60
# 13	90
# 16	120
# 19	150
# 22	180
# 25	210
# 28	240
# 31	270
# 34	300
# 37	330
# 40	360
# 43	390
# 46	420
# 49	450
# 52	480
# 55	510
# 58	540
# 61	570
# 64	600
# 67	630
# 70	660
# 73	690
# 76	720
# 79	750
# 82	780
# 85	810
# 88	840
# 91	870
# 94	900
# 97	930
#
# ['10', '13', '16', '19', '22', '25', '28', '31', '34', '37', '40', '43', '46', '49', '52', '55', '58', '61', '64', '67', '70', '73', '76', '79', '82', '85', '88', '91', '94', '97']
# ['60', '90', '120', '150', '180', '210', '240', '270', '300', '330', '360', '390', '420', '450', '480', '510', '540', '570', '600', '630', '660', '690', '720', '750', '780', '810', '840', '870', '900', '930']

# %%
import pandas as pd

pd.set_option('display.max_rows', 500)

with open('data.txt', 'r') as file:
  data = file.read()
  x = []
  y = []
  # print(data)
  file.seek(0)

  for line in file:
    line_split = line.replace('\n', '').split('\t')
    x.append(line_split[0])
    y.append(line_split[1])

  df = pd.DataFrame({'x': x, 'y': y})

  # print(x)
  # print(y)
  print(df)
# Out:
#      x    y
# 0   10   60
# 1   13   90
# 2   16  120
# 3   19  150
# 4   22  180
# 5   25  210
# 6   28  240
# 7   31  270
# 8   34  300
# 9   37  330
# 10  40  360
# 11  43  390
# 12  46  420
# 13  49  450
# 14  52  480
# 15  55  510
# 16  58  540
# 17  61  570
# 18  64  600
# 19  67  630
# 20  70  660
# 21  73  690
# 22  76  720
# 23  79  750
# 24  82  780
# 25  85  810
# 26  88  840
# 27  91  870
# 28  94  900
# 29  97  930

# %%
import pandas as pd

new_df = pd.read_table('data.txt', header=None, names=('X','Y'))
print(new_df)
# Out:
#      X    Y
# 0   10   60
# 1   13   90
# 2   16  120
# 3   19  150
# 4   22  180
# 5   25  210
# 6   28  240
# 7   31  270
# 8   34  300
# 9   37  330
# 10  40  360
# 11  43  390
# 12  46  420
# 13  49  450
# 14  52  480
# 15  55  510
# 16  58  540
# 17  61  570
# 18  64  600
# 19  67  630
# 20  70  660
# 21  73  690
# 22  76  720
# 23  79  750
# 24  82  780
# 25  85  810
# 26  88  840
# 27  91  870
# 28  94  900
# 29  97  930

# %%
import pandas as pd

url = "https://raw.github.com/pandas-dev/pandas/main/pandas/tests/io/data/csv/tips.csv"
tips = pd.read_csv(url)

tips
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
import opendatasets as od

dataset_url = "https://www.kaggle.com/datasets/danofer/law-school-admissions-bar-passage"

od.download(dataset_url, data_dir="./data", force=True)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Downloading law-school-admissions-bar-passage.zip to ./data/law-school-admissions-bar-passage
# 100%|██████████| 494k/494k [00:00<00:00, 3.55MB/s]

# %% [markdown]
# ## Importing from APIs

# %%
import requests
import pandas as pd

host= 'https://api.census.gov/data'
year= '2022'
dataset='cps/basic/apr'

url = "/".join([host, year, dataset])

predicates= {}
predicates["get"]= ",".join(["GEDIV","HRMIS","PENATVTY"])
predicates["for"] = "state:*"

response = requests.get(url, params=predicates)

census_data = pd.DataFrame.from_records(response.json()[1:], columns=response.json()[0])

census_data.head(5)
# Out:
#   GEDIV HRMIS PENATVTY state
# 0     8     8      303     4
# 1     8     8      303     4
# 2     8     8       57     4
# 3     8     8       57     4
# 4     7     2       57     5

# %%
import requests

HOST = "https://api.census.gov/data"
year = "2017"
dataset = "acs/acs5"
base_url = "/".join([HOST, year, dataset]) # JOIN the variables with a `/` separator https://api.census.gov/data/2022/cps/basic/apr

dataset_variables = ["NAME"]
predicates = {}
predicates["get"] = ",".join(dataset_variables)
predicates["for"] = "state:*"

r = requests.get(base_url, params=predicates)
states = pd.DataFrame.from_records(r.json()[1:], columns=r.json()[0])
states.head()
# Out:
#           NAME state
# 0  Mississippi    28
# 1     Missouri    29
# 2      Montana    30
# 3     Nebraska    31
# 4       Nevada    32

# %%
states[states["NAME"]== 'Ohio']
# Out:
#     NAME state
# 16  Ohio    39

# %%
full_census_data = pd.merge(census_data, states, on='state')
full_census_data.head()
# Out:
#   GEDIV HRMIS PENATVTY state      NAME
# 0     7     6       57    40  Oklahoma
# 1     7     6       57    40  Oklahoma
# 2     7     6       57    40  Oklahoma
# 3     7     6       57    40  Oklahoma
# 4     7     3       57    40  Oklahoma

# %%
full_census_data = full_census_data.drop(columns=['state'])
full_census_data.head()
# Out:
#   GEDIV HRMIS PENATVTY      NAME
# 0     7     6       57  Oklahoma
# 1     7     6       57  Oklahoma
# 2     7     6       57  Oklahoma
# 3     7     6       57  Oklahoma
# 4     7     3       57  Oklahoma

# %%
full_census_data = full_census_data.rename(columns={'NAME': 'STATE'})
full_census_data.head()
# Out:
#   GEDIV HRMIS PENATVTY     STATE
# 0     7     6       57  Oklahoma
# 1     7     6       57  Oklahoma
# 2     7     6       57  Oklahoma
# 3     7     6       57  Oklahoma
# 4     7     3       57  Oklahoma

# %% [markdown]
# ## Another Example

# %%
import os
from dotenv import load_dotenv
import requests

load_dotenv(override=True)
rapid_api_key = os.getenv("RAPID_API_KEY")

url = "https://covid-19-statistics.p.rapidapi.com/reports"
request_params = {"region_province":"Ohio","iso":"USA","region_name":"US","q":"US Ohio","date":"2020-04-16"}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "covid-19-statistics.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=request_params)

# save json result into a pandas dataframe
covid_data = pd.DataFrame(response.json()["data"][0]["region"]["cities"])
covid_data.head()
# Out:
#         name        date   fips          lat          long  confirmed  deaths  \
# 0      Adams  2020-04-16  39001  38.84541072   -83.4718964          3       0
# 1      Allen  2020-04-16  39003  40.77285242  -84.10802343         57       6
# 2    Ashland  2020-04-16  39005  40.84772277  -82.27280781          5       0
# 3  Ashtabula  2020-04-16  39007  41.70860332  -80.74830218         45       3
# 4     Athens  2020-04-16  39009  39.33425634  -82.04278644          3       1
#
#    confirmed_diff  deaths_diff          last_update
# 0               0            0  2020-04-16 23:30:51
# 1               6            2  2020-04-16 23:30:51
# 2              -1            0  2020-04-16 23:30:51
# 3               9            0  2020-04-16 23:30:51
# 4               0            0  2020-04-16 23:30:51

# %% [markdown]
# ## From SQL

# %%
from urllib.request import urlretrieve
from zipfile import ZipFile

file_handle, _ = urlretrieve('https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip')
zipfile = ZipFile(file_handle, 'r')
zipfile.extractall('./data')
zipfile.close();

# %%
from sqlalchemy import create_engine
import pandas as pd

connection_string = 'sqlite:///data/chinook.db'
engine = create_engine(connection_string)

db_connection = engine.connect()

genres_data = pd.read_sql(sql='SELECT * FROM genres;', con=db_connection)

genres_data
# Out:
#     GenreId                Name
# 0         1                Rock
# 1         2                Jazz
# 2         3               Metal
# 3         4  Alternative & Punk
# 4         5       Rock And Roll
# 5         6               Blues
# 6         7               Latin
# 7         8              Reggae
# 8         9                 Pop
# 9        10          Soundtrack
# 10       11          Bossa Nova
# 11       12      Easy Listening
# 12       13         Heavy Metal
# 13       14            R&B/Soul
# 14       15   Electronica/Dance
# 15       16               World
# 16       17         Hip Hop/Rap
# 17       18     Science Fiction
# 18       19            TV Shows
# 19       20    Sci Fi & Fantasy
# 20       21               Drama
# 21       22              Comedy
# 22       23         Alternative
# 23       24           Classical
# 24       25               Opera

# %%
genres_data = pd.concat([
  genres_data,
  pd.DataFrame.from_records([{'GenreId': '26', 'Name': 'Arabic Pop'}])
], ignore_index= True)
genres_data
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll
# 5        6               Blues
# 6        7               Latin
# 7        8              Reggae
# 8        9                 Pop
# 9       10          Soundtrack
# 10      11          Bossa Nova
# 11      12      Easy Listening
# 12      13         Heavy Metal
# 13      14            R&B/Soul
# 14      15   Electronica/Dance
# 15      16               World
# 16      17         Hip Hop/Rap
# 17      18     Science Fiction
# 18      19            TV Shows
# 19      20    Sci Fi & Fantasy
# 20      21               Drama
# 21      22              Comedy
# 22      23         Alternative
# 23      24           Classical
# 24      25               Opera
# 25      26          Arabic Pop

# %%
genres_data.to_sql('genres', db_connection, if_exists='replace', index=False)
# Out:
# 26

# %%
genres_data2 = pd.read_sql(sql='SELECT * FROM genres;', con=db_connection)

genres_data2
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll
# 5        6               Blues
# 6        7               Latin
# 7        8              Reggae
# 8        9                 Pop
# 9       10          Soundtrack
# 10      11          Bossa Nova
# 11      12      Easy Listening
# 12      13         Heavy Metal
# 13      14            R&B/Soul
# 14      15   Electronica/Dance
# 15      16               World
# 16      17         Hip Hop/Rap
# 17      18     Science Fiction
# 18      19            TV Shows
# 19      20    Sci Fi & Fantasy
# 20      21               Drama
# 21      22              Comedy
# 22      23         Alternative
# 23      24           Classical
# 24      25               Opera
# 25      26          Arabic Pop

# %% [markdown]
# ## From Mongo DB

# %%
import os
from dotenv import load_dotenv
from pymongo import MongoClient
import pandas as pd

pd.set_option('display.max_columns', None)

load_dotenv(override=True)

mongo_user = os.getenv('MONGO_USERNAME')
mongo_password = os.getenv('MONGO_PASSWORD')
mongo_host= 'cluster0.9u8bdoy.mongodb.net'

mongo_uri="mongodb+srv://%s:%s@%s/?retryWrites=true&w=majority" % (mongo_user, mongo_password, mongo_host)

mongo_conn = MongoClient(mongo_uri)['sample_airbnb']

reviews = mongo_conn['listingsAndReviews'].find({
  'bedrooms': {"$lt": 3}
})

reviews_dataframe = pd.DataFrame(list(reviews))
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
# 1   1001265   https://www.airbnb.com/rooms/1001265
# 2  10021707  https://www.airbnb.com/rooms/10021707
# 3  10030955  https://www.airbnb.com/rooms/10030955
# 4   1003530   https://www.airbnb.com/rooms/1003530
#
#                                   name  \
# 0         Horto flat with small garden
# 1     Ocean View Waikiki Marina w/prkg
# 2             Private Room in Bushwick
# 3          Apt Linda Vista Lagoa - Rio
# 4  New York City - Upper West Side Apt
#
#                                              summary  \
# 0  One bedroom + sofa-bed in quiet and bucolic ne...
# 1  A short distance from Honolulu's billion dolla...
# 2  Here exists a very cozy room for rent in a sha...
# 3  Quarto com vista para a Lagoa Rodrigo de Freit...
# 4
#
#                                                space  \
# 0  Lovely one bedroom + sofa-bed in the living ro...
# ...

# %%
reviews_dataframe.head(10)
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
# 1   1001265   https://www.airbnb.com/rooms/1001265
# 2  10021707  https://www.airbnb.com/rooms/10021707
# 3  10030955  https://www.airbnb.com/rooms/10030955
# 4   1003530   https://www.airbnb.com/rooms/1003530
# 5  10038496  https://www.airbnb.com/rooms/10038496
# 6  10047964  https://www.airbnb.com/rooms/10047964
# 7  10051164  https://www.airbnb.com/rooms/10051164
# 8  10057447  https://www.airbnb.com/rooms/10057447
# 9  10057826  https://www.airbnb.com/rooms/10057826
#
#                                   name  \
# 0         Horto flat with small garden
# 1     Ocean View Waikiki Marina w/prkg
# 2             Private Room in Bushwick
# 3          Apt Linda Vista Lagoa - Rio
# 4  New York City - Upper West Side Apt
# 5         Copacabana Apartment Posto 6
# 6       Charming Flat in Downtown Moda
# 7   Catete's Colonial Big Hause Room B
# ...

# %%
reviews_dataframe.describe()
# Out:
#        accommodates     bedrooms         beds  number_of_reviews  \
# count   4894.000000  4894.000000  4883.000000        4894.000000
# mean       2.975889     1.121373     1.705918          28.239886
# std        1.608095     0.556239     1.057319          50.730294
# min        1.000000     0.000000     0.000000           0.000000
# 25%        2.000000     1.000000     1.000000           1.000000
# 50%        2.000000     1.000000     1.000000           6.000000
# 75%        4.000000     1.000000     2.000000          33.000000
# max       16.000000     2.000000    12.000000         533.000000
#
#        reviews_per_month
# count          85.000000
# mean            1.741176
# std             1.551903
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             2.000000
# max            10.000000

# %% [markdown]
# ## Via Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/Wealth_distribution_by_country'
page = requests.get(url)

soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.find_all('table')

wealth_df = pd.read_html(str(tables[0]))[0]
wealth_df.head()
# Out:
#    nation  percent of world population  share of adult population  \
# 0     USA                         4.67                      71.39
# 1  Canada                         0.50                      74.18
# 2     NaN                          NaN                        NaN
# 3   total                         5.17                        NaN
#
#    Net worth per capita (PPP)  Net worth per capita (exchange rates)  \
# 0                    143727.0                               143727.0
# 1                     89252.0                                70916.0
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
#
#    Percent of world net worth (PPP)  \
# 0                              25.4
# 1                               1.7
# 2                               NaN
# 3                              27.1
#
#    Percent of world net worth (exchange rates)  Real GDP per capita (PPP)  \
# ...

# %%
wealth_df = wealth_df[:-2]
wealth_df
# Out:
#    nation  percent of world population  share of adult population  \
# 0     USA                         4.67                      71.39
# 1  Canada                         0.50                      74.18
#
#    Net worth per capita (PPP)  Net worth per capita (exchange rates)  \
# 0                    143727.0                               143727.0
# 1                     89252.0                                70916.0
#
#    Percent of world net worth (PPP)  \
# 0                              25.4
# 1                               1.7
#
#    Percent of world net worth (exchange rates)  Real GDP per capita (PPP)  \
# 0                                        32.65                    35619.0
# 1                                         1.74                    28731.0
#
#    Real GDP per capita (exchange rates)  Percent of world GDP (PPP)  \
# 0                               35619.0                       21.97
# 1                               22828.0                        1.91
#
# ...

# %%
len(tables)
# Out:
# 8

# %%
for i in range(1, len(tables)):
  wealth_df = pd.concat([wealth_df, pd.read_html(str(tables[i]))[0]], ignore_index=True)
  wealth_df = wealth_df[:-2]

wealth_df
# Out:
#                          nation  percent of world population  \
# 0                           USA                         4.67
# 1                        Canada                         0.50
# 2                     Argentina                         0.61
# 3                       Bahamas                         0.00
# 4                      Barbados                         0.00
# 5                        Belize                         0.00
# 6                       Bermuda                         0.00
# 7                       Bolivia                         0.14
# 8                        Brazil                         2.86
# 9                         Chile                         0.25
# 10                     Colombia                         0.69
# 11                   Costa Rica                         0.06
# 12                         Cuba                         0.18
# 13           Dominican Republic                         0.14
# ...
